# %% [markdown]
# # Bioinformatics Table of Contents
#
# <!---
# ### Lecture Slides
# * [Bioinformatics Pipeline Slides](bioinformatics_overview.pdf)
#
# #### TODO
# * Add intro text to each notebooks with overview of what it will cover
# * add in md5sum discussion (in QC?)
#
#
# data_provenance.ipynb
# quality_scores.ipynb
# -->
#
#
#
#
# ## Basic Bioinformatics Pipeline
# <!---
# 1. [Demultiplex Raw FASTQs](filled_nb/demultiplex.ipynb) ([clean notebook](clean_nb/demultiplex_clean.ipynb))
# -->
# 1. [Introduction to FASTQs](fastq_intro.ipynb)
# 1. [Quality Control](fastqc.ipynb)
# 1. [Trimming and Filtering](fastq_trimming.ipynb)
# 1. [Download and Index Genome](genome_prep.ipynb)
# 1. [Mapping Reads to a Reference Genome](mapping.ipynb)
# 1. [Counting Reads](counting.ipynb)
#
# ## Extending the Bioinformatics Pipeline
# 1. [Working with Paired Reads](paired_data_pipeline.ipynb)
# 1. [Making Generic Commands](making_generic_commands.ipynb)
# 1. [Making a Pipeline](making_a_pipeline.ipynb)
# 1. [Pipeline in a Loop](loop_pipeline.ipynb)
# 1. [Running Multiple FASTQs](multifastq_loop_pipeline.ipynb)
# 1. [Looping with Globs](glob_loop.ipynb)
#
# <!---
# 1. [Pipeline with Loops](filled_nb/loop_pipeline.ipynb) ([clean notebook](clean_nb/loop_pipeline_clean.ipynb))
# 1. [Pipeline for Multiple Samples](filled_nb/full_pilot_data_pipeline.ipynb) ([clean notebook](clean_nb/full_pilot_data_pipeline_clean.ipynb))
#
# ## Pipeline for All 2015 Data
#
# 1. [Demultiplex All 2015 Data](filled_nb/full_2015_data_demux.ipynb)
# 1. [Demuxed FASTQ to Counts for All 2015 Data](filled_nb/full_2015_data_pipeline.ipynb)
#
# -->
#
# ## Hands On Exercies
# 1. [Hands On Exercise #1](bioinf_hands_on_1.ipynb)
#
# ## Appendix
# * [Quality Scores](quality_scores.ipynb)
#
# <!---
#
# * [IGV visualization](filled_nb/igv_visualization.ipynb)
#
# -->
#
# <!---
# * [Using Bash in a Python Notebook](filled_nb/bash_magic.ipynb)
#
# ## Parallelize
# * https://unix.stackexchange.com/questions/103920/parallelize-a-bash-for-loop
# * https://stackoverflow.com/questions/38160/parallelize-bash-script-with-maximum-number-of-processes
# * https://stackoverflow.com/questions/38774355/how-to-parallelize-for-loop-in-bash-limiting-number-of-processes
# -->
#
# <!---
#
# ## Bonus
# * [Does Filtering Matter? Mapping unfiltered paired reads](filled_nb/paired_pilot_data_pipeline_unfiltered.ipynb)
#
# # Below Here Needs Checking
# 1. [putting_it_together](filled_nb/putting_it_together.ipynb) ([clean notebook](clean_nb/putting_it_together_clean.ipynb))
# 1. [demux_exploration](filled_nb/demux_exploration.ipynb) ([clean notebook](clean_nb/demux_exploration_clean.ipynb))
# 1. [annotation_prep](filled_nb/annotation_prep.ipynb) ([clean notebook](clean_nb/annotation_prep_clean.ipynb))
# 1. [putting_it_together_all_data](filled_nb/putting_it_together_all_data.ipynb) ([clean notebook](clean_nb/putting_it_together_all_data_clean.ipynb))
# 1. [working_with_your_data](filled_nb/working_with_your_data.ipynb) ([clean notebook](clean_nb/working_with_your_data_clean.ipynb))
# 1. [annotation](filled_nb/annotation.ipynb) ([clean notebook](clean_nb/annotation_clean.ipynb))
#
# #### Bioinformatics Pipeline on Full Dataset
#
# #### Differential Expression Analysis
# 1. [DESeq2-Notebook](filled_nb/DESeq2-Notebook.ipynb) ([clean notebook](clean_nb/DESeq2-Notebook_clean.ipynb))
# 1. [DESeq2-Notebook-from-Matrix](filled_nb/DESeq2-Notebook-from-Matrix.ipynb) ([clean notebook](clean_nb/DESeq2-Notebook-from-Matrix_clean.ipynb))
#
# ### Additional Information
# * [Update Notebooks](filled_nb/update_notebooks.ipynb)
# * [Resources](https://github.com/granek/microbiome_workshop#resources)
#
# -->
