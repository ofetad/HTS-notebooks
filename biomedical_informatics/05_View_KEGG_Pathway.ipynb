# %% [markdown]
# # Set environment

# %%
source("Pathway_config.R")
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats
# Loading required package: org.Hs.eg.db
# Loading required package: AnnotationDbi
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# ...

# %%
dir(INFODIR)
# Out:
# [1] "genesets_cne.gmt"                 "h99_jec21_syntenic_orthologs.txt"
# [3] "jec21_h99_syntenic_orthologs.txt" "pathway_genes.txt"
# [5] "pathway_ids.txt"                  "pathway_names.txt"
# [7] "PathwaysByGeneIds_Summary.txt"

# %% [markdown]
# # get the gene list

# %%
attach(file.path(OUTDIR, "pathway_genesets.RData"))

# %%
# change working directory, since pathview saves output in working directory
# and doesn't have option to specify an alternative
setwd(OUTDIR)

# %%
pathview(
    gene.data = genesets_cne_jec[[1]],
    pathway.id = "00010",
    species = "cne",
    gene.idtype = "kegg",
    #kegg.dir = IMGDIR,
    kegg.native = T,
    same.layer=T)
# Out:
# Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
# ...

# %%
display_png(file="cne00010.pathview.png")

# %%
genelst <- genesets_cne_jec[[1]]
tmp <- seq(-1, 1, length.out = length(genelst))
#tmp <- 1:length(genelst)
names(tmp) <- genelst
print(tmp)
# Out:
#    CNA00470    CNA07130    CNA07740    CNB00300    CNB02660    CNB04050
# -1.00000000 -0.94117647 -0.88235294 -0.82352941 -0.76470588 -0.70588235
#    CNC00160    CNC01860    CNC03080    CNC05140    CND02060    CND02450
# -0.64705882 -0.58823529 -0.52941176 -0.47058824 -0.41176471 -0.35294118
#    CND05840    CNE00040    CNE00710    CNE05000    CNE05250    CNF03160
# -0.29411765 -0.23529412 -0.17647059 -0.11764706 -0.05882353  0.00000000
#    CNF03900    CNF04450    CNG00600    CNG02220    CNH01400    CNI00320
#  0.05882353  0.11764706  0.17647059  0.23529412  0.29411765  0.35294118
#    CNI03590    CNJ00950    CNJ01080    CNK00280    CNK01070    CNL05070
#  0.41176471  0.47058824  0.52941176  0.58823529  0.64705882  0.70588235
#    CNL05600    CNM00220    CNM00290    CNM01690    CNN00430
#  0.76470588  0.82352941  0.88235294  0.94117647  1.00000000

# %%
pathview(
    gene.data = tmp,
    out.suffix = "sequential_label",
    pathway.id = "00010",
    species = "cne",
    gene.idtype = "kegg",
    kegg.dir = IMGDIR,
    kegg.native = T,
    same.layer=T)
# Out:
# Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
#   Consider 'structure(list(), *)' instead.”Warning message in structure(x$children, class = "XMLNodeList"):
# “Calling 'structure(NULL, *)' is deprecated, as NULL cannot have attributes.
# ...

# %%
display_png(file="cne00010.sequential_label.png")
